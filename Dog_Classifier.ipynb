# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyushSawarkar/Dog_Classifier/blob/master/Dog_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras import backend as K
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras.models import Model
from keras.applications import imagenet_utils
import numpy as np
from IPython.display import Image
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
mobile = keras.applications.mobilenet.MobileNet()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
def prepare_image(file):
    img_path = ''
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
# !wget https://cdn3-www.dogtime.com/assets/uploads/gallery/german-shepherd-dog-breed-pictures/standing-7.jpg
# Out:
# --2020-03-24 10:30:27--  https://cdn3-www.dogtime.com/assets/uploads/gallery/german-shepherd-dog-breed-pictures/standing-7.jpg
# Resolving cdn3-www.dogtime.com (cdn3-www.dogtime.com)... 104.17.70.15, 104.17.69.15
# Connecting to cdn3-www.dogtime.com (cdn3-www.dogtime.com)|104.17.70.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49751 (49K) [image/jpeg]
# Saving to: ‘standing-7.jpg.1’
#
# standing-7.jpg.1    100%[===================>]  48.58K  --.-KB/s    in 0.01s
#
# 2020-03-24 10:30:27 (3.83 MB/s) - ‘standing-7.jpg.1’ saved [49751/49751]

# %%
Image(filename='standing-7.jpg')

# %%
preprocessed_image = prepare_image('standing-7.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# [[('n02106662', 'German_shepherd', 0.8227632),
#   ('n02105162', 'malinois', 0.16620645),
#   ('n02093754', 'Border_terrier', 0.00267227),
#   ('n02093991', 'Irish_terrier', 0.0024468235),
#   ('n02114367', 'timber_wolf', 0.0014540745)]]

# %%
# !wget http://elelur.com/data_images/dog-breeds/standard-poodle/standard-poodle-04.jpg
# Out:
# --2020-03-24 10:40:31--  http://elelur.com/data_images/dog-breeds/standard-poodle/standard-poodle-04.jpg
# Resolving elelur.com (elelur.com)... 138.201.95.42
# Connecting to elelur.com (elelur.com)|138.201.95.42|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 675959 (660K) [image/jpeg]
# Saving to: ‘standard-poodle-04.jpg’
#
# standard-poodle-04. 100%[===================>] 660.12K  1.25MB/s    in 0.5s
#
# 2020-03-24 10:40:32 (1.25 MB/s) - ‘standard-poodle-04.jpg’ saved [675959/675959]

# %%
Image(filename='standard-poodle-04.jpg')

# %%
preprocessed_image = prepare_image('standard-poodle-04.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02113799', 'standard_poodle', 0.6032771),
#   ('n02113712', 'miniature_poodle', 0.3793987),
#   ('n02113624', 'toy_poodle', 0.016594527),
#   ('n02104029', 'kuvasz', 0.0002183176),
#   ('n02088094', 'Afghan_hound', 0.00017858628)]]

# %%
# !wget https://cdn1-www.dogtime.com/assets/uploads/gallery/old-english-sheepdog-dog-breed-pictures/side-5.jpg
# Out:
# --2020-03-24 10:42:19--  https://cdn1-www.dogtime.com/assets/uploads/gallery/old-english-sheepdog-dog-breed-pictures/side-5.jpg
# Resolving cdn1-www.dogtime.com (cdn1-www.dogtime.com)... 104.17.70.15, 104.17.69.15
# Connecting to cdn1-www.dogtime.com (cdn1-www.dogtime.com)|104.17.70.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58695 (57K) [image/jpeg]
# Saving to: ‘side-5.jpg’
#
# side-5.jpg          100%[===================>]  57.32K  --.-KB/s    in 0.01s
#
# 2020-03-24 10:42:19 (4.54 MB/s) - ‘side-5.jpg’ saved [58695/58695]

# %%
Image(filename='side-5.jpg')

# %%
preprocessed_image = prepare_image('side-5.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n02105641', 'Old_English_sheepdog', 0.6266879),
#   ('n02093647', 'Bedlington_terrier', 0.18475035),
#   ('n02095889', 'Sealyham_terrier', 0.03852921),
#   ('n02097130', 'giant_schnauzer', 0.02385009),
#   ('n02095314', 'wire-haired_fox_terrier', 0.014298877)]]
